# %% [markdown]
# # P.VIJAY SRINIVASAN -INTERN AT SPARKS FOUNDATION

# %% [markdown]
# # GRIP PROGRAM JAN 2021-TASK NO 2

# %% [markdown]
# # TASK 2-PREDICTION USING SUPERVISED ML USING TREE CLASSIFIER

# %% [markdown]
# # THE IRIS CLASSIFIER DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv('iris.csv')
iris.columns=['id','SepalLength','SepalWidth','PetalLength','PetalWidth','Species']
iris
# Out:
#       id  SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 145  146          6.7         3.0          5.2         2.3  Iris-virginica
# 146  147          6.3         2.5          5.0         1.9  Iris-virginica
# 147  148          6.5         3.0          5.2         2.0  Iris-virginica
# 148  149          6.2         3.4          5.4         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.describe()
# Out:
#                id  SepalLength  SepalWidth  PetalLength  PetalWidth
# count  150.000000   150.000000  150.000000   150.000000  150.000000
# mean    75.500000     5.843333    3.054000     3.758667    1.198667
# std     43.445368     0.828066    0.433594     1.764420    0.763161
# min      1.000000     4.300000    2.000000     1.000000    0.100000
# 25%     38.250000     5.100000    2.800000     1.600000    0.300000
# 50%     75.500000     5.800000    3.000000     4.350000    1.300000
# 75%    112.750000     6.400000    3.300000     5.100000    1.800000
# max    150.000000     7.900000    4.400000     6.900000    2.500000

# %%
iris.isnull().sum()
# NO NULL VALUES
# Out:
# id             0
# SepalLength    0
# SepalWidth     0
# PetalLength    0
# PetalWidth     0
# Species        0
# dtype: int64

# %%
fig,ax=plt.subplots(1,1,figsize=(20,20))
plt.subplot(2,1,1)
sns.scatterplot(x='SepalLength',y='PetalLength',hue='Species',data=iris)
plt.subplot(2,1,2)
sns.scatterplot(x='SepalWidth',y='PetalWidth',hue='Species',data=iris)
# Out:
# <AxesSubplot:xlabel='SepalWidth', ylabel='PetalWidth'>

# %%
# fig,ax=plt.subplots(4,4,figsize=(20,20))
sns.heatmap(iris.corr(),annot=True)
iris.corr()
# Out:
#                    id  SepalLength  SepalWidth  PetalLength  PetalWidth
# id           1.000000     0.716676   -0.397729     0.882747    0.899759
# SepalLength  0.716676     1.000000   -0.109369     0.871754    0.817954
# SepalWidth  -0.397729    -0.109369    1.000000    -0.420516   -0.356544
# PetalLength  0.882747     0.871754   -0.420516     1.000000    0.962757
# PetalWidth   0.899759     0.817954   -0.356544     0.962757    1.000000

# %%
fig,ax=plt.subplots(1,1,figsize=(30,30))
plt.subplot(2,1,1)
sns.boxplot(x='PetalLength',y='SepalLength',hue='Species',data=iris)
plt.subplot(2,1,2)
sns.boxplot(x='PetalWidth',y='SepalWidth',hue='Species',data=iris)
# Out:
# <AxesSubplot:xlabel='PetalWidth', ylabel='SepalWidth'>

# %%
fig,ax=plt.subplots(1,1,figsize=(30,20))
plt.subplot(2,1,1)
sns.swarmplot(x='PetalLength',y='SepalLength',hue='Species',data=iris)
plt.subplot(2,1,2)
sns.swarmplot(x='PetalWidth',y='SepalWidth',hue='Species',data=iris)
# Out:
# <AxesSubplot:xlabel='PetalWidth', ylabel='SepalWidth'>

# %% [markdown]
# # Now let's train the machine using a classification algorithm called DECISION TREE CLASSIFIER which
# # mostly works based on many if or else conditions

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
X=iris.drop('Species',axis=1)
y=iris['Species']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
X_train
y_train
# Out:
# 34         Iris-setosa
# 21         Iris-setosa
# 60     Iris-versicolor
# 121     Iris-virginica
# 81     Iris-versicolor
#             ...
# 139     Iris-virginica
# 115     Iris-virginica
# 17         Iris-setosa
# 129     Iris-virginica
# 39         Iris-setosa
# Name: Species, Length: 120, dtype: object

# %% [markdown]
# # Predicting the model and converting into dataframe by testing it on one of the features(SepalWidth here)

# %%
model=DecisionTreeClassifier(max_depth=4).fit(X_train,y_train)
model
predict=model.predict(X_test)
pd.DataFrame(predict,index=X_test['SepalWidth'],columns={'Species'})
# Out:
#                     Species
# SepalWidth
# 3.0          Iris-virginica
# 2.8         Iris-versicolor
# 3.3             Iris-setosa
# 3.5             Iris-setosa
# 3.9             Iris-setosa
# 2.7         Iris-versicolor
# 2.6          Iris-virginica
# 3.1         Iris-versicolor
# 3.6             Iris-setosa
# 2.5          Iris-virginica
# 3.4         Iris-versicolor
# 2.9         Iris-versicolor
# 2.5         Iris-versicolor
# 2.7         Iris-versicolor
# 3.4             Iris-setosa
# 3.0             Iris-setosa
# 3.1             Iris-setosa
# 4.2             Iris-setosa
# 3.1             Iris-setosa
# 3.8             Iris-setosa
# 3.3         Iris-versicolor
# 2.7          Iris-virginica
# 2.9         Iris-versicolor
# 3.2          Iris-virginica
# 3.0         Iris-versicolor
# 3.4             Iris-setosa
# 3.7             Iris-setosa
# 2.8          Iris-virginica
# 3.3          Iris-virginica
# 2.3             Iris-setosa

# %% [markdown]
# # Visualizing the working of  decision tree

# %%
features=['SepalLength','SepalWidth','PetalLength','PetalWidth']
target=['setosa','versicolor','virginica']
plt.figure(figsize=(20,20))
plot_tree(model,feature_names=features,class_names=target,filled=True)
# Out:
# [Text(446.4, 906.0, 'PetalWidth <= 2.45\ngini = 0.667\nsamples = 120\nvalue = [40, 41, 39]\nclass = versicolor'),
#  Text(223.2, 543.6, 'gini = 0.0\nsamples = 40\nvalue = [40, 0, 0]\nclass = setosa'),
#  Text(669.5999999999999, 543.6, 'SepalLength <= 100.5\ngini = 0.5\nsamples = 80\nvalue = [0, 41, 39]\nclass = versicolor'),
#  Text(446.4, 181.19999999999993, 'gini = 0.0\nsamples = 41\nvalue = [0, 41, 0]\nclass = versicolor'),
#  Text(892.8, 181.19999999999993, 'gini = 0.0\nsamples = 39\nvalue = [0, 0, 39]\nclass = virginica')]

# %% [markdown]
# # THANK YOU
