# %% [markdown]
# # P.Vijay Srinivasan
#
#
# # IPL DATA ANALYSIS AND VISUALIZATION

# %% [markdown]
# # THE SPARKS FOUNDATION
# # GRIP PROGRAM TASK-GRIP JAN 2021
# # TASK-5 EXPLORATORY DATA ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # THIS DATA WAS TOO LONG TO PLOT ,SO I SEPERATED THE DATA BASED ON COLUMN CONTAINING SEASONS AND NOW THERE ARE 5 IPL SEASONS OF YEAR 2008,2009,2010,2011 AND 2017
# # LET'S SEE THE OVERALL STATISTICS OF THE IPL TEAMS AND PERFORMANCE OF THE PLAYERS IN THESE MENTIONED SEASONS

# %%
matches=pd.read_csv('matches.csv')
matches.shape
matches.rename({'id':'match_id'},inplace=True,axis=1)
matches=matches.head(300)
matches1=matches[matches['season']==2008]
matches2=matches[matches['season']==2009]
matches3=matches[matches['season']==2010]
matches4=matches[matches['season']==2011]
matches7=matches[matches['season']==2012]
matches5=matches[matches['season']==2017]
matches6=matches[matches['season']==2019]
print(matches['season'].unique())
# print(matches1)
# print(matches2)
# print(matches3)
# print(matches4)
# print(matches5)
# matches6

# df1=pd.merge(deliveries,matches,on='match_id')
# df1.isnull().sum()
# df1['batting_team']
# df1.groupby('date').head()
# df1.sort_values('team1',ascending=False)
# df1.columns
# matches.set_index('id')
# matches['batting']=matches[matches['toss_decision']=='bat']

# data1=pd.merge(deliveries,matches,on='id')
# Out:
# [2017 2008 2009 2010 2011]

# %% [markdown]
# # NOW LET'S VISUALIZE THE  PROBABLITY OF BATTING OR FIELDING FOR EACH TEAM IN EACH SEASON

# %%
fig,ax=plt.subplots(5,5,figsize=(30,40))
plt.subplot(5,1,1)
sns.countplot(x='toss_decision',hue='winner',data=matches1)
plt.title('IPL 2008')
plt.subplot(5,1,2)
plt.title('IPL 2009')
sns.countplot(x='toss_decision',hue='winner',data=matches2)
plt.subplot(5,1,3)
sns.countplot(x='toss_decision',hue='winner',data=matches3)
plt.title('IPL 2010')
plt.subplot(5,1,4)
plt.title('IPL 2011')
sns.countplot(x='toss_decision',hue='winner',data=matches4)
plt.subplot(5,1,5)
sns.countplot(x='toss_decision',hue='winner',data=matches5)
plt.title('IPL 2017')
# Out:
# Text(0.5, 1.0, 'IPL 2017')

# %% [markdown]
# # decision of batting or fielding of each team for season2 2008,2009,2010,2011,2017
# # who took the highest decision of taking batting and fielding in these seasons?

# %% [markdown]
# # 2008-BATTING:Chennai Super Kings FIELDING:Mumbai Indians
# # 2009-BATTING:Royal challengers,FIELDING:Delhi daredevils
# # 2010-BATTING:Chennai Super Kings,Fielding:Mumbai Indians
# # 2011-BATTING:Chennai Super Kings,Fielding:5 teams Royal challengers,mumbai indians,punjab,delhi and kerala took highest number of batting
# # 2017-BATTING:Mumbai Indians(very low number of batting first),Fielding:Rising Pune SuperGiants

# %% [markdown]
# # THIS VISUAL SHOWS US WHICH TEAM MAXIMUN NUMBER OF TIMES WON THE TOSS IN EACH SEASON

# %%
fig,ax=plt.subplots(5,5,figsize=(20,20))
plt.subplot(5,1,1)
plt.xticks(rotation=0)
sns.countplot(x='toss_winner',hue='season',data=matches1)
plt.subplot(5,1,2)
plt.xticks(rotation=0)
sns.countplot(x='toss_winner',hue='season',data=matches2)
plt.subplot(5,1,3)
plt.xticks(rotation=0)
sns.countplot(x='toss_winner',hue='season',data=matches3)
plt.subplot(5,1,4)
plt.xticks(rotation=0)
# plt.figure(figsize=(10,10))
sns.countplot(x='toss_winner',hue='season',data=matches4)
plt.subplot(5,1,5)
plt.xticks(rotation=0)
# plt.figure(figsize=(10,10))
sns.countplot(x='toss_winner',hue='season',data=matches5)
# plt.show()
# Out:
# <AxesSubplot:xlabel='toss_winner', ylabel='count'>

# %% [markdown]
# # team which won the toss most of the times are:
#
# # 2008-Rajasthan Royals
# # 2009-Deccan Chargers
# # 2010-Chennai Super Kings
# # 2011-KingsXI Punjab
# # 2017-Mumbai indians

# %% [markdown]
# # THIS FOLLOWING GRAPHS EXPLAINS WHICH STADIUM DID ALL TEAMS PLAY AND HOW MANY TIMES THEY PLAYED IN THAT STADIUM

# %%
fig,ax=plt.subplots(1,1,figsize=(40,50))
plt.subplot(5,1,1)
plt.title('IPL 2008')
plt.legend(loc=1)
plt.xticks(rotation=10)
sns.countplot(x='venue',hue='winner',data=matches1)
plt.subplot(5,1,2)
plt.title('IPL 2009')
sns.countplot(x='venue',hue='winner',data=matches2)
plt.legend(loc=1)
plt.subplot(5,1,3)
plt.title('IPL 2010')
plt.xticks(rotation=10)
sns.countplot(x='venue',hue='winner',data=matches3)
plt.subplot(5,1,4)
plt.title('IPL 2011')
plt.xticks(rotation=10)
sns.countplot(x='venue',hue='winner',data=matches4)
plt.subplot(5,1,5)
plt.title('IPL 2017')
plt.xticks(rotation=10)
sns.countplot(x='venue',hue='winner',data=matches5)
# Out:
# No handles with labels found to put in legend.
# <AxesSubplot:title={'center':'IPL 2012'}, xlabel='venue', ylabel='count'>

# %% [markdown]
# # Which stadium they played most of the times?
#
#
# # 2008-Sawai Mansingh Stadium,Rajasthan Royals won most of the times
# # 2009-Kingsmeade-RCB and Delhi won most times,New wandear stadium-RCB
# # 2010-Brabourne Stadium-Mumbai Indians won most times
# # 2011-MA Chidambaram stadium,Chennai,CSK won most of the times
# # 2017-Rajiv Gandhi International Stadium,Uppal,PUNE won most of the times

# %% [markdown]
# # this one gives us the probablity of batting or fielding in each season

# %%
fig,ax=plt.subplots(5,5,figsize=(20,20))
plt.subplot(5,1,1)
sns.countplot(x='toss_decision',hue='season',data=matches1)
plt.subplot(5,1,2)
sns.countplot(x='toss_decision',hue='season',data=matches2)
plt.subplot(5,1,3)
sns.countplot(x='toss_decision',hue='season',data=matches3)
plt.subplot(5,1,4)
sns.countplot(x='toss_decision',hue='season',data=matches4)
plt.subplot(5,1,5)
sns.countplot(x='toss_decision',hue='season',data=matches5)
# Out:
# <AxesSubplot:xlabel='toss_decision', ylabel='count'>

# %% [markdown]
# # what the toss decision was?BATTING OR FIELDING?
#
# # 2008-Fielding
# # 2009-Batting
# # 2010-Batting
# # 2011-Fielding
# # 2017-Fielding

# %% [markdown]
# # using this visual,we can see the which player is the man of the match and how many times he was for each season

# %%
fig,ax=plt.subplots(1,1,figsize=(30,30))
plt.subplot(5,1,1)
plt.xticks(rotation=40)
plt.title('IPL 2008')
x=matches3['player_of_match'].value_counts()
plt.bar(x.keys(),x)
# sns.countplot(x='player_of_match',hue='winner',data=matches1)
plt.subplot(5,1,2)
plt.title('IPL 2009')
plt.xticks(rotation=40)
sns.countplot(x='player_of_match',hue='winner',data=matches2)
plt.subplot(5,1,3)
plt.title('IPL 2010')
plt.xticks(rotation=40)
sns.countplot(x='player_of_match',hue='winner',data=matches3)
plt.subplot(5,1,4)
plt.title('IPL 2011')
plt.xticks(rotation=40)
sns.countplot(x='player_of_match',hue='winner',data=matches4)
plt.subplot(5,1,5)
plt.title('IPL 2017')
plt.xticks(rotation=40)
sns.countplot(x='player_of_match',hue='winner',data=matches5)
# Out:
# <AxesSubplot:title={'center':'IPL 2017'}, xlabel='player_of_match', ylabel='count'>

# %% [markdown]
# # Which player was maximum number of times man of the match?
#
# # 2008-SE Marsh-5 times man of the match
# # 2009-Yusuf pathan-3 times man of the match
# # 2010-Sachin Tendulkar-4 times man of the match
# # 2011-Harbhajan singh -4 times man of the match
# # 2017-Ben Stokes-3 times man of the match and NM Counter Nile- 3 times

# %% [markdown]
# # most of us will be eager to know which team won by how many runs and how many times did they win
# # this graph gives us how many times did they win by run differences
# # for each season

# %%
fig,ax=plt.subplots(1,1,figsize=(30,40))
plt.subplot(5,1,1)
plt.title('IPL 2008')
sns.countplot(x='win_by_runs',hue='winner',data=matches1)
plt.subplot(5,1,2)
plt.title('IPL 2009')
sns.countplot(x='win_by_runs',hue='winner',data=matches2)
plt.subplot(5,1,3)
plt.title('IPL 2010')
sns.countplot(x='win_by_runs',hue='winner',data=matches3)
plt.subplot(5,1,4)
plt.title('IPL 2011')
sns.countplot(x='win_by_runs',hue='winner',data=matches4)
plt.subplot(5,1,5)
plt.title('IPL 2017')
sns.countplot(x='win_by_runs',hue='winner',data=matches5)
# Out:
# <AxesSubplot:title={'center':'IPL 2017'}, xlabel='win_by_runs', ylabel='count'>

# %% [markdown]
# we can see which team won by difference in wickets and number of times they won by difference in wickets

# %%
fig,ax=plt.subplots(1,1,figsize=(30,30))
plt.legend(loc=1)
plt.subplot(5,1,1)
plt.title('IPL 2008')
sns.countplot(x='win_by_wickets',hue='winner',data=matches1)
plt.subplot(5,1,2)
plt.title('IPL 2009')
sns.countplot(x='win_by_wickets',hue='winner',data=matches2)
plt.subplot(5,1,3)
plt.title('IPL 2010')
sns.countplot(x='win_by_wickets',hue='winner',data=matches3)
plt.subplot(5,1,4)
plt.title('IPL 2011')
sns.countplot(x='win_by_wickets',hue='winner',data=matches4)
plt.subplot(5,1,5)
plt.title('IPL 2017')
sns.countplot(x='win_by_wickets',hue='winner',data=matches5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # using bar plot,we can know which team mostly won by wickets

# %%
fig,ax=plt.subplots(1,1,figsize=(20,20))
plt.legend(loc=1)
plt.subplot(5,1,1)
plt.title('IPL 2008')
sns.barplot(x='team2',y='win_by_wickets',hue='winner',data=matches1)
plt.subplot(5,1,2)
plt.title('IPL 2009') 
sns.barplot(x='team2',y='win_by_wickets',hue='winner',data=matches2)
plt.subplot(5,1,3)
plt.title('IPL 2010') 
sns.barplot(x='team2',y='win_by_wickets',hue='winner',data=matches3)
plt.subplot(5,1,4)
plt.title('IPL 2011')
sns.barplot(x='team2',y='win_by_wickets',hue='winner',data=matches4)
plt.subplot(5,1,5)
plt.title('IPL 2017')
sns.barplot(x='team2',y='win_by_wickets',hue='winner',data=matches5)
# Out:
# No handles with labels found to put in legend.
# <AxesSubplot:title={'center':'IPL 2017'}, xlabel='team2', ylabel='win_by_wickets'>

# %% [markdown]
# #  Which team won higest number of times by difference in wickets?
#
# # 2008-Deccan Chargers won mostly by 8 wickets
# # 2009-Mumbai Indians won by nearly 7 wickets mostly
# # 2010-Rajasthan Royals won mostly by 9 wickets
# # 2011-Mumbai Indians won mostly by 8 wickets
# # 2017-Punjab won most of times with nearly 8 wickets difference

# %% [markdown]
# # which team mostly won by difference in runs

# %% [markdown]
# # 2008-RAJASTHAN ROYALS WON IN HUGE DIFFERENCE OF 60 RUNS
# # 2009-Chennai Super Kings
# # 2010-Mumbai Indians
# # 2011-Kings XI Punjab
# # 2017-Delhi DareDevils

# %%
fig,ax=plt.subplots(1,1,figsize=(30,40))
plt.legend(loc=1)
plt.subplot(5,1,1)
plt.title('IPL 2008')
sns.barplot(x='team1',y='win_by_runs',hue='winner',data=matches1)
plt.subplot(5,1,2)
plt.title('IPL 2009')
sns.barplot(x='team1',y='win_by_runs',hue='winner',data=matches2)
plt.subplot(5,1,3)
plt.title('IPL 2010')
sns.barplot(x='team1',y='win_by_runs',hue='winner',data=matches3)
plt.subplot(5,1,4)
plt.title('IPL 2011')
sns.barplot(x='team1',y='win_by_runs',hue='winner',data=matches4)
plt.subplot(5,1,5)
plt.title('IPL 2017')
sns.barplot(x='team1',y='win_by_runs',hue='winner',data=matches5)
# Out:
# No handles with labels found to put in legend.
# <AxesSubplot:title={'center':'IPL 2017'}, xlabel='team1', ylabel='win_by_runs'>

# %% [markdown]
# # which team won mostly by difference in runs?
# # 2008-Rajasthan Royals with nearly 60 runs
# # 2009-Chennai Super Kings wirh nearly 45 runs
# # 2010-Mumbai Indians with nearly 45 runs
# # 2011-Kings Xi Punjab with nearly 45 runs
# # 2017-Delhi daredevils with nearly 40 runs

# %% [markdown]
# # VISUALIZATION ON MS DHONI IN IPL

# %% [markdown]
# # LET'S CALCULATE OUR Legend MS DHONI PERFORMANCE IN Each SEASONS vs SOME GREAT  teams

# %%
matches1=matches1[matches1['player_of_match']=='MS Dhoni']
matches2=matches2[matches2['player_of_match']=='MS Dhoni']
matches3=matches3[matches3['player_of_match']=='MS Dhoni']
matches4=matches4[matches4['player_of_match']=='MS Dhoni']
matches5=matches5[matches5['player_of_match']=='MS Dhoni']
fig,ax=plt.subplots(1,1,figsize=(40,40))
plt.subplot(7,1,1)
plt.title('CSK VS DELHI(2008)')
sns.countplot(x='team1',hue='player_of_match',data=matches1,palette='plasma')
plt.subplot(7,1,2)
plt.title('CSK VS RCB(2008)')
sns.countplot(x='team2',hue='player_of_match',data=matches1)
plt.subplot(7,1,3)
plt.title('CSK VS DECCAN CHARGERS(2009)')
sns.countplot(x='team2',hue='player_of_match',data=matches2)
plt.subplot(7,1,4)
plt.title('CSK VS DELHI(2010)')
sns.countplot(x='team2',hue='player_of_match',data=matches3)
plt.subplot(7,1,5)
plt.title('CSK VS KXIP(2010)')
sns.countplot(x='team1',hue='player_of_match',data=matches3)
plt.subplot(7,1,6)
plt.title('CSK VS DELHI(2011)')
sns.countplot(x='team2',hue='player_of_match',data=matches4)
plt.subplot(7,1,7)
plt.title('CSK VS SRH(2017)')
sns.countplot(x='team1',hue='player_of_match',data=matches5)
# Out:
# <AxesSubplot:title={'center':'CSK VS SRH(2017)'}, xlabel='team1', ylabel='count'>

# %% [markdown]
# # Against which team  MS Dhoni was player of the match?
#
# # 2008- CSK VS DELHI,CSK VS RCB -2 times
# # 2009-CSK VS DECCAN CHARGERS-1 time
# # 2010-CSK VS DELHI,CSK VS PUNJAB-2 times
# # 2011-CSK VS DELHI-1 time
# # 2017-CSK VS SRH -1 time

# %% [markdown]
# # MAN OF THE MATCH ISN'T A EASY POSITION TO GET,IT REQUIRES AN IMMENSE LEVEL OF CONFIDENCE AND CRITICAL DECISION MAKING.
# # LET'S SEE WHAT WAS MS DHONI'S TOSS DECISION VS OTHER TEAMS WHEN HE WAS MAN OF THAT MATCH

# %%
fig,ax=plt.subplots(1,1,figsize=(40,40))
plt.subplot(7,1,1)
plt.title('CSK VS Delhi(2008)')
sns.countplot(x='toss_decision',hue='team1',data=matches1)
plt.subplot(7,1,2)
plt.title('CSK VS RCB(2008)')
sns.countplot(x='toss_decision',hue='team2',data=matches1)
plt.subplot(7,1,3)
plt.title('CSK VS DECCAN CHARGERS(2009)')
sns.countplot(x='toss_decision',hue='team2',data=matches2)
plt.subplot(7,1,4)
plt.title('CSK VS DELHI(2010)')
sns.countplot(x='toss_decision',hue='team2',data=matches3)
plt.subplot(7,1,5)
plt.title('CSK VS KXIP(2010)')
sns.countplot(x='toss_decision',hue='team1',data=matches3)
plt.subplot(7,1,6)
plt.title('CSK VS DELHI(2011)')
sns.countplot(x='toss_decision',hue='team2',data=matches4)
plt.subplot(7,1,7)
plt.title('CSK VS SRH(2017)')
sns.countplot(x='toss_decision',hue='team1',data=matches5)
# Out:
# <AxesSubplot:title={'center':'CSK VS SRH(2017)'}, xlabel='toss_decision', ylabel='count'>

# %% [markdown]
# # MAN OF THE MATCH ISN'T A EASY TITLE TO GET WHERE TOSS DECISION ,TOO PLAYS AN IMPORTANT ROLE
# # What was MS Dhoni's toss decision when he was man of the match?
# # 2008-batting VS Delhi,batting VS RCB
# # 2009-batting VS Deccan
# # 2010-batting VS Kolkata,Fielding vs Punjab
# # 2011-batting VS Delhi
# # 2017-fielding VS SRH

# %%
deliveries=pd.read_csv('deliveries.csv')
# deliveries['match_id']=deliveries['match_id'].unique()
# deliveries.set_index('match_id','inning')
# deliveries=deliveries.rename(columns={'match_id':'id'},inplace=True)
deliveries.columns=['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
       'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
       'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
       'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
       'dismissal_kind', 'fielder']
null_sum=deliveries.isnull().sum()
null_perc=null_sum/179078*100
null_data=pd.DataFrame(null_perc,columns=['percentage'])
null_data
# deliveries=deliveries['bowling_team'].unique()
deliveries1=deliveries[deliveries['bowling_team']=='Royal Challengers Bangalore']
deliveries2=deliveries[deliveries['bowling_team']=='Mumbai Indians']
deliveries3=deliveries[deliveries['bowling_team']=='Delhi Daredevils']
deliveries4=deliveries[deliveries['bowling_team']=='Rajasthan Royals']
deliveries5=deliveries[deliveries['bowling_team']=='Sunrisers Hyderabad']
deliveries6=deliveries[deliveries['bowling_team']=='Kings XI Punjab']
deliveries7=deliveries[deliveries['bowling_team']=='Kolkata Knight Riders']
deliveries8=deliveries[deliveries['bowling_team']=='Chennai Super Kings']
# deliveries1=deliveries1[deliveries1['bowling_team']=='Mumbai Indians']
print(deliveries1)
print(deliveries2)
print(deliveries3)
print(deliveries4)
print(deliveries5)
print(deliveries6)
print(deliveries7)
print(deliveries8)
# print(deliveries)
# runs=deliveries8[deliveries8['bowling_team']=='Kings XI Punjab']
# plt.figure(figsize=(40,40))
# plt.xticks(rotation=90)
# sns.barplot(x='batsman',y='total_runs',hue='over',data=deliveries8)
# plt.figure(figsize=(30,30))
# sns.barplot(x='batsman',y='batsman_runs',data=deliveries8)
# plt.xticks(rotation=90)

# deliveries1=deliveries1.groupby('bowler')['wide_runs'].sum()
# deliveries1.plot()
# plt.xticks(rotation=90)
# # # deliveries=deliveries.dropna(null_data['percentage']>95)
# deliveries.dropna()

# deliveries.dropna()
# deliveries['batting_team'].head(40)
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 177511     11345       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 177512     11345       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 177513     11345       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 177514     11345       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 177515     11345       1  Sunrisers Hyderabad  Royal Challengers Bangalore
#
# ...

# %%
#

# %%
fig,ax=plt.subplots(1,1,figsize=(30,40))
plt.subplot(8,1,1)
sns.barplot(x='bowling_team',y='wide_runs',data=deliveries1)

plt.subplot(8,1,2)
sns.barplot(x='bowling_team',y='wide_runs',data=deliveries2)

plt.subplot(8,1,3)
sns.barplot(x='bowling_team',y='wide_runs',data=deliveries3)

plt.subplot(8,1,4)
sns.barplot(x='bowling_team',y='wide_runs',data=deliveries4)

plt.subplot(8,1,5)
sns.barplot(x='bowling_team',y='wide_runs',data=deliveries5)

plt.subplot(8,1,6)
sns.barplot(x='bowling_team',y='wide_runs',data=deliveries6)

plt.subplot(8,1,7)
sns.barplot(x='bowling_team',y='wide_runs',data=deliveries7)

plt.subplot(8,1,8)
sns.barplot(x='bowling_team',y='wide_runs',data=deliveries8,palette='cool')
# Out:
# <AxesSubplot:xlabel='bowling_team', ylabel='wide_runs'>

# %% [markdown]
# # Which team has bowled most number of wides in which over?
# # it gives us which team had given  more number of wide runs and in which over

# %%
fig,ax=plt.subplots(1,1,figsize=(30,30))
plt.subplot(8,1,1)
sns.barplot(x='over',y='wide_runs',hue='bowling_team',data=deliveries1)
plt.subplot(8,1,2)
sns.barplot(x='over',y='wide_runs',hue='bowling_team',data=deliveries2)
plt.subplot(8,1,3)
sns.barplot(x='over',y='wide_runs',hue='bowling_team',data=deliveries3)
plt.subplot(8,1,4)
sns.barplot(x='over',y='wide_runs',hue='bowling_team',data=deliveries4)
plt.subplot(8,1,5)
sns.barplot(x='over',y='wide_runs',hue='bowling_team',data=deliveries5)
plt.subplot(8,1,6)
sns.barplot(x='over',y='wide_runs',hue='bowling_team',data=deliveries6)
plt.subplot(8,1,7)
sns.barplot(x='over',y='wide_runs',hue='bowling_team',data=deliveries7)
plt.subplot(8,1,8)
sns.barplot(x='over',y='wide_runs',hue='bowling_team',data=deliveries8)


# plt.sub
# Out:
# <AxesSubplot:xlabel='over', ylabel='wide_runs'>

# %%
'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %% [markdown]
# # Which team has bowled most number of legbye in which over?
# # it gives us which team had given  more number of legbye runs and in which over

# %%
fig,ax=plt.subplots(1,1,figsize=(30,30))
plt.subplot(811)
sns.barplot(x='over',y='legbye_runs',hue='bowling_team',data=deliveries1,palette='winter')
plt.subplot(812)
sns.barplot(x='over',y='legbye_runs',hue='bowling_team',data=deliveries2,palette='ocean')
plt.subplot(813)
sns.barplot(x='over',y='legbye_runs',hue='bowling_team',data=deliveries3,palette='Accent_r')
plt.subplot(814)
sns.barplot(x='over',y='legbye_runs',hue='bowling_team',data=deliveries4,palette='Paired')
plt.subplot(815)
sns.barplot(x='over',y='legbye_runs',hue='bowling_team',data=deliveries5,palette='Pastel1')
plt.subplot(816)
sns.barplot(x='over',y='legbye_runs',hue='bowling_team',data=deliveries6,palette='Wistia')
plt.subplot(817)
sns.barplot(x='over',y='legbye_runs',hue='bowling_team',data=deliveries7,palette='YlGn')
plt.subplot(818)
sns.barplot(x='over',y='legbye_runs',hue='bowling_team',data=deliveries8,palette='Set3')
# Out:
# <AxesSubplot:xlabel='over', ylabel='legbye_runs'>

# %%
fig,ax=plt.subplots(1,1,figsize=(30,30))
plt.subplot(811)
sns.barplot(x='over',y='bye_runs',hue='bowling_team',data=deliveries1,palette='winter')
plt.subplot(812)
sns.barplot(x='over',y='bye_runs',hue='bowling_team',data=deliveries2,palette='ocean')
plt.subplot(813)
sns.barplot(x='over',y='bye_runs',hue='bowling_team',data=deliveries3,palette='Accent_r')
plt.subplot(814)
sns.barplot(x='over',y='bye_runs',hue='bowling_team',data=deliveries4,palette='Paired')
plt.subplot(815)
sns.barplot(x='over',y='bye_runs',hue='bowling_team',data=deliveries5,palette='Pastel1')
plt.subplot(816)
sns.barplot(x='over',y='bye_runs',hue='bowling_team',data=deliveries6,palette='Wistia')
plt.subplot(817)
sns.barplot(x='over',y='bye_runs',hue='bowling_team',data=deliveries7,palette='YlGn')
plt.subplot(818)
sns.barplot(x='over',y='bye_runs',hue='bowling_team',data=deliveries8,palette='Set3')
# Out:
# <AxesSubplot:xlabel='over', ylabel='bye_runs'>

# %% [markdown]
# # Which team gave most number of noball runs in which over?

# %%
fig,ax=plt.subplots(1,1,figsize=(30,30))
plt.subplot(811)
sns.barplot(x='over',y='noball_runs',hue='bowling_team',data=deliveries1,palette='winter')
plt.subplot(812)
sns.barplot(x='over',y='noball_runs',hue='bowling_team',data=deliveries2,palette='ocean')
plt.subplot(813)
sns.barplot(x='over',y='noball_runs',hue='bowling_team',data=deliveries3,palette='Accent_r')
plt.subplot(814)
sns.barplot(x='over',y='noball_runs',hue='bowling_team',data=deliveries4,palette='Paired')
plt.subplot(815)
sns.barplot(x='over',y='noball_runs',hue='bowling_team',data=deliveries5,palette='Pastel1')
plt.subplot(816)
sns.barplot(x='over',y='noball_runs',hue='bowling_team',data=deliveries6,palette='Wistia')
plt.subplot(817)
sns.barplot(x='over',y='noball_runs',hue='bowling_team',data=deliveries7,palette='YlGn')
plt.subplot(818)
sns.barplot(x='over',y='noball_runs',hue='bowling_team',data=deliveries8,palette='Set3')
# Out:
# <AxesSubplot:xlabel='over', ylabel='noball_runs'>

# %% [markdown]
# # on merging the given two data sets,we can see the analysis for each over and how many wides,noball,legbye runs and bye were there for each over and which team has mostly performed many wides/noballs

# %% [markdown]
# # OVER ANALYSIS

# %% [markdown]
# # Which team bowled most number of wides in which season?
#
#
#
# # this graphs shows us the solution for the this question

# %%
# deliveries=deliveries[deliveries['team1']=='Chennai Super Kings']
df=pd.merge(deliveries,matches,on='match_id')
# df=df[df['season']==2008]
df['batting_team'].unique()
plt.figure(figsize=(30,30))
sns.barplot(x='wide_runs',y='bowling_team',hue='season',data=df)
# df[df['batsman']=='MS Dhoni'].count()
# Out:
# <AxesSubplot:xlabel='wide_runs', ylabel='bowling_team'>

# %% [markdown]
# #  Which team had bowled many wides in each season?
#
# # 2008-KKR bowled many wides in 2008
# # 2009-MI
# # 2010-KXIP
# # 2011-KXIP
# # 2017-RCB

# %% [markdown]
# # Which team bowled most number of noball runs in which season?
#
#
#
# # this graphs shows us the solution for the this question

# %%
plt.figure(figsize=(30,30))
sns.barplot(x='noball_runs',y='bowling_team',hue='season',data=df)
# Out:
# <AxesSubplot:xlabel='noball_runs', ylabel='bowling_team'>

# %% [markdown]
# # Which team had bowled more number of noball runs in which season?
# # 2008-KOLKATA
# # 2009-DELHI
# # 2010-PUNJAB
# # 2011-BANGALORE
# # 2017-MUMBAI

# %% [markdown]
# # Which team gave most number of legbye runs in which season?
#
#
#
# # this graphs shows us the solution for the this question

# %%
plt.figure(figsize=(20,20))
sns.barplot(x='legbye_runs',y='bowling_team',hue='season',data=df)
# Out:
# <AxesSubplot:xlabel='legbye_runs', ylabel='bowling_team'>

# %% [markdown]
# # Which team had bowled more number of legbye runs in which season?
#
# # 2008-Deccan Chargers
# # 2009-MUMBAI
# # 2010-RCB
# # 2011-PUNJAB

# %% [markdown]
# # Which player got dismissed more times in ipl and at which over he got dismissed in each season?
# # this graph gives us dismissal of  a individual player  and at which  over he got dismissed

# %%
df1=df[df['season']==2008]
df2=df[df['season']==2009]
df3=df[df['season']==2010]
df4=df[df['season']==2011]
df5=df[df['season']==2017]
fig,ax=plt.subplots(5,5,figsize=(30,30))
plt.subplot(5,1,1)
x=df1['player_dismissed'].value_counts().sort_values(ascending=False).head(10)
plt.title('Ipl 2008')
plt.bar(x.keys(),x)
plt.subplot(5,1,2)
plt.title('Ipl 2009')
y=df2['player_dismissed'].value_counts().sort_values(ascending=False).head(10)
plt.bar(y.keys(),y)
plt.subplot(5,1,3)
plt.title('Ipl 2010')
z=df3['player_dismissed'].value_counts().sort_values(ascending=False).head(10)
plt.bar(z.keys(),z,label='Players who got dismissed')
plt.subplot(5,1,4)
plt.title('Ipl 2011')
a=df4['player_dismissed'].value_counts().sort_values(ascending=False).head(10)
plt.bar(a.keys(),a,label='Players who got dismissed')
plt.subplot(5,1,5)
plt.title('Ipl 2017')
b=df5['player_dismissed'].value_counts().sort_values(ascending=False).head(10)
plt.bar(b.keys(),b,label='Players who got dismissed')
# sns.countplot(x=x,hue='season',data=df)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# # Which player got dismissed most of the times in ipl?
#
# # 2008-Yusuf Pathan 14 times
# # 2009-Adam Gilchrist 16 times
# # 2010-ML Hayden 16 times
# # 2011-Adam Gilchrist 14 times
# # 2017-Parthiv Patel 16 times

# %%
plt.figure(figsize=(20,30))
plt.xticks(rotation=30)
plt.ylim(0,3500)
sns.countplot(x='winner',hue='season',data=df)
# Out:
# <AxesSubplot:xlabel='winner', ylabel='count'>

# %% [markdown]
# # Which team won most of the matches in each season?
#
#
# # 2008-Rajasthan Royals
# # 2009-Delhi Daredevils
# # 2010-Mumbai Indians
# # 2011-Chennai Super Kings
# # 2017-Mumbai Indians
